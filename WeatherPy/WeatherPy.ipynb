# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observation 1:
# Southern Hemisphere climates tend to be slightly milder than those at similar latitudes in the Northern Hemisphere. This is because the Southern Hemisphere has significantly more ocean and much less land; water heats up and cools down more slowly than land.
#
# Observation 2:
# Highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature drops. This happens as equatorial region receives sunlight straight with less or no angle due to curvature shape of earth.
#
# Observation 3:
# Latitude doesn't have a strong iinfluence on wind speed. The speed of the wind is controlled by the strength of the air pressure gradient, the stronger the pressure gradient the higher the wind speed.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : bredasdorp
# Processing Record 2 of Set 1 : kruisfontein
# Processing Record 3 of Set 1 : port hardy
# Processing Record 4 of Set 1 : port alfred
# City not found. Skipping...
# Processing Record 5 of Set 1 : batsfjord
# Processing Record 6 of Set 1 : vaini
# Processing Record 7 of Set 1 : taoudenni
# Processing Record 8 of Set 1 : atuona
# Processing Record 9 of Set 1 : chuy
# Processing Record 10 of Set 1 : dingle
# Processing Record 11 of Set 1 : rikitea
# Processing Record 12 of Set 1 : new norfolk
# Processing Record 13 of Set 1 : jamestown
# Processing Record 14 of Set 1 : fairbanks
# Processing Record 15 of Set 1 : alyangula
# Processing Record 16 of Set 1 : ciudad bolivar
# Processing Record 17 of Set 1 : punta arenas
# Processing Record 18 of Set 1 : albany
# Processing Record 19 of Set 1 : chokurdakh
# Processing Record 20 of Set 1 : kayerkan
# Processing Record 21 of Set 1 : mataura
# Processing Record 22 of Set 1 : merauke
# Processing Record 23 of Set 1 : lagoa
# Processing Record 24 of Set 1 : east london
# Processing Record 25 of Set 1 : ushuaia
# Processing Record 26 of Set 1 : hobart
# Processing Record 27 of Set 1 : husavik
# Processing Record 28 of Set 1 : zhaoyuan
# Processing Record 29 of Set 1 : golspie
# Processing Record 30 of Set 1 : berdsk
# Processing Record 31 of Set 1 : moindou
# Processing Record 32 of Set 1 : ilhabela
# Processing Record 33 of Set 1 : peskovka
# Processing Record 34 of Set 1 : vila franca do campo
# City not found. Skipping...
# Processing Record 35 of Set 1 : saint-joseph
# Processing Record 36 of Set 1 : izhma
# Processing Record 37 of Set 1 : upernavik
# Processing Record 38 of Set 1 : thompson
# Processing Record 39 of Set 1 : codrington
# Processing Record 40 of Set 1 : nikolskoye
# Processing Record 41 of Set 1 : esil
# Processing Record 42 of Set 1 : eufaula
# Processing Record 43 of Set 1 : spring hill
# Processing Record 44 of Set 1 : hermanus
# Processing Record 45 of Set 1 : tuktoyaktuk
# Processing Record 46 of Set 1 : belyy yar
# Processing Record 47 of Set 1 : asau
# City not found. Skipping...
# Processing Record 48 of Set 1 : malia
# Processing Record 49 of Set 1 : komsomolskiy
# Processing Record 50 of Set 1 : lewistown
# Processing Record 0 of Set 2 : kemin
# City not found. Skipping...
# Processing Record 1 of Set 2 : inhambane
# Processing Record 2 of Set 2 : shakawe
# Processing Record 3 of Set 2 : busselton
# Processing Record 4 of Set 2 : puerto ayora
# Processing Record 5 of Set 2 : qaanaaq
# Processing Record 6 of Set 2 : toppenish
# Processing Record 7 of Set 2 : hobyo
# Processing Record 8 of Set 2 : mahibadhoo
# Processing Record 9 of Set 2 : severo-kurilsk
# Processing Record 10 of Set 2 : kerrville
# Processing Record 11 of Set 2 : binghamton
# Processing Record 12 of Set 2 : georgetown
# Processing Record 13 of Set 2 : north platte
# Processing Record 14 of Set 2 : fortuna
# Processing Record 15 of Set 2 : mar del plata
# Processing Record 16 of Set 2 : kiama
# Processing Record 17 of Set 2 : castro
# Processing Record 18 of Set 2 : barrow
# Processing Record 19 of Set 2 : ajdabiya
# Processing Record 20 of Set 2 : banyumas
# Processing Record 21 of Set 2 : nome
# Processing Record 22 of Set 2 : klaksvik
# Processing Record 23 of Set 2 : butaritari
# Processing Record 24 of Set 2 : hasaki
# Processing Record 25 of Set 2 : mahebourg
# Processing Record 26 of Set 2 : oranjemund
# Processing Record 27 of Set 2 : mahendragarh
# Processing Record 28 of Set 2 : srednekolymsk
# Processing Record 29 of Set 2 : san cristobal
# Processing Record 30 of Set 2 : hasanpur
# Processing Record 31 of Set 2 : altay
# Processing Record 32 of Set 2 : isetskoye
# Processing Record 33 of Set 2 : san policarpo
# City not found. Skipping...
# Processing Record 34 of Set 2 : medina
# Processing Record 35 of Set 2 : mandera
# Processing Record 36 of Set 2 : shingu
# Processing Record 37 of Set 2 : kapaa
# City not found. Skipping...
# Processing Record 38 of Set 2 : malgobek
# Processing Record 39 of Set 2 : nanortalik
# Processing Record 40 of Set 2 : vila velha
# Processing Record 41 of Set 2 : caucaia
# City not found. Skipping...
# Processing Record 42 of Set 2 : constanta
# Processing Record 43 of Set 2 : port elizabeth
# Processing Record 44 of Set 2 : pangody
# Processing Record 45 of Set 2 : saint-pierre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 2 : qasigiannguit
# Processing Record 47 of Set 2 : yellowknife
# Processing Record 48 of Set 2 : mumbwa
# Processing Record 49 of Set 2 : mariinsk
# Processing Record 50 of Set 2 : bluff
# Processing Record 0 of Set 3 : savannah bight
# Processing Record 1 of Set 3 : constitucion
# Processing Record 2 of Set 3 : adrar
# Processing Record 3 of Set 3 : lompoc
# Processing Record 4 of Set 3 : naryan-mar
# Processing Record 5 of Set 3 : koumac
# Processing Record 6 of Set 3 : hualmay
# Processing Record 7 of Set 3 : airai
# Processing Record 8 of Set 3 : tutoia
# Processing Record 9 of Set 3 : khatanga
# Processing Record 10 of Set 3 : sinnamary
# Processing Record 11 of Set 3 : anadyr
# Processing Record 12 of Set 3 : talnakh
# Processing Record 13 of Set 3 : cherskiy
# Processing Record 14 of Set 3 : souillac
# Processing Record 15 of Set 3 : kamenka
# Processing Record 16 of Set 3 : arraial do cabo
# City not found. Skipping...
# Processing Record 17 of Set 3 : carnarvon
# Processing Record 18 of Set 3 : northam
# City not found. Skipping...
# Processing Record 19 of Set 3 : chumikan
# Processing Record 20 of Set 3 : tuatapere
# Processing Record 21 of Set 3 : nuuk
# Processing Record 22 of Set 3 : cockburn town
# Processing Record 23 of Set 3 : aklavik
# Processing Record 24 of Set 3 : saskylakh
# Processing Record 25 of Set 3 : slupca
# Processing Record 26 of Set 3 : lydenburg
# Processing Record 27 of Set 3 : longyearbyen
# Processing Record 28 of Set 3 : clyde river
# City not found. Skipping...
# Processing Record 29 of Set 3 : walvis bay
# Processing Record 30 of Set 3 : huntsville
# City not found. Skipping...
# Processing Record 31 of Set 3 : barcani
# Processing Record 32 of Set 3 : sioux lookout
# Processing Record 33 of Set 3 : kavieng
# City not found. Skipping...
# Processing Record 34 of Set 3 : kudahuvadhoo
# Processing Record 35 of Set 3 : uyuni
# Processing Record 36 of Set 3 : hilo
# Processing Record 37 of Set 3 : nizhniy tsasuchey
# Processing Record 38 of Set 3 : manyana
# Processing Record 39 of Set 3 : flin flon
# Processing Record 40 of Set 3 : shache
# Processing Record 41 of Set 3 : ponta do sol
# Processing Record 42 of Set 3 : port hedland
# Processing Record 43 of Set 3 : tiarei
# Processing Record 44 of Set 3 : bairnsdale
# Processing Record 45 of Set 3 : zyryanskoye
# Processing Record 46 of Set 3 : faya
# Processing Record 47 of Set 3 : markova
# Processing Record 48 of Set 3 : san quintin
# Processing Record 49 of Set 3 : arlit
# Processing Record 50 of Set 3 : tasiilaq
# Processing Record 0 of Set 4 : yulara
# Processing Record 1 of Set 4 : mwene-ditu
# Processing Record 2 of Set 4 : goderich
# Processing Record 3 of Set 4 : cape town
# Processing Record 4 of Set 4 : saint george
# Processing Record 5 of Set 4 : mount gambier
# Processing Record 6 of Set 4 : silifke
# Processing Record 7 of Set 4 : ribeira grande
# Processing Record 8 of Set 4 : dunedin
# Processing Record 9 of Set 4 : camacha
# City not found. Skipping...
# Processing Record 10 of Set 4 : xining
# Processing Record 11 of Set 4 : aksu
# Processing Record 12 of Set 4 : avarua
# Processing Record 13 of Set 4 : harseni
# Processing Record 14 of Set 4 : barcelos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 4 : milkovo
# Processing Record 16 of Set 4 : sri aman
# Processing Record 17 of Set 4 : pisco
# Processing Record 18 of Set 4 : palmer
# Processing Record 19 of Set 4 : bethel
# Processing Record 20 of Set 4 : yenotayevka
# Processing Record 21 of Set 4 : esperance
# Processing Record 22 of Set 4 : mana
# Processing Record 23 of Set 4 : bengkulu
# Processing Record 24 of Set 4 : acapulco
# Processing Record 25 of Set 4 : colares
# Processing Record 26 of Set 4 : vardo
# Processing Record 27 of Set 4 : aykhal
# Processing Record 28 of Set 4 : liberal
# Processing Record 29 of Set 4 : havre-saint-pierre
# Processing Record 30 of Set 4 : maragogi
# Processing Record 31 of Set 4 : yen bai
# Processing Record 32 of Set 4 : aloleng
# Processing Record 33 of Set 4 : ruwi
# Processing Record 34 of Set 4 : norman wells
# Processing Record 35 of Set 4 : coquimbo
# Processing Record 36 of Set 4 : chapais
# Processing Record 37 of Set 4 : cabo san lucas
# Processing Record 38 of Set 4 : lorengau
# Processing Record 39 of Set 4 : dikson
# Processing Record 40 of Set 4 : kemi
# Processing Record 41 of Set 4 : katsuura
# Processing Record 42 of Set 4 : zhangjiakou
# Processing Record 43 of Set 4 : puerto escondido
# Processing Record 44 of Set 4 : koungou
# Processing Record 45 of Set 4 : deputatskiy
# Processing Record 46 of Set 4 : salalah
# Processing Record 47 of Set 4 : rawson
# Processing Record 48 of Set 4 : nata
# Processing Record 49 of Set 4 : palu
# Processing Record 50 of Set 4 : gubkinskiy
# Processing Record 0 of Set 5 : carbonia
# Processing Record 1 of Set 5 : layog
# Processing Record 2 of Set 5 : vihti
# Processing Record 3 of Set 5 : los llanos de aridane
# Processing Record 4 of Set 5 : leningradskiy
# Processing Record 5 of Set 5 : seoul
# Processing Record 6 of Set 5 : kodiak
# Processing Record 7 of Set 5 : pevek
# City not found. Skipping...
# Processing Record 8 of Set 5 : narsaq
# City not found. Skipping...
# Processing Record 9 of Set 5 : nova olimpia
# Processing Record 10 of Set 5 : maryville
# Processing Record 11 of Set 5 : baiyin
# Processing Record 12 of Set 5 : warrington
# Processing Record 13 of Set 5 : aldan
# Processing Record 14 of Set 5 : kokkola
# Processing Record 15 of Set 5 : nichinan
# Processing Record 16 of Set 5 : geraldton
# Processing Record 17 of Set 5 : saint-philippe
# Processing Record 18 of Set 5 : ostrovnoy
# Processing Record 19 of Set 5 : lebu
# City not found. Skipping...
# Processing Record 20 of Set 5 : cidreira
# Processing Record 21 of Set 5 : tabas
# Processing Record 22 of Set 5 : banda aceh
# Processing Record 23 of Set 5 : lavrentiya
# Processing Record 24 of Set 5 : faanui
# Processing Record 25 of Set 5 : dalgopol
# Processing Record 26 of Set 5 : negombo
# Processing Record 27 of Set 5 : ulladulla
# Processing Record 28 of Set 5 : lago da pedra
# Processing Record 29 of Set 5 : guerrero negro
# Processing Record 30 of Set 5 : the valley
# Processing Record 31 of Set 5 : aksay
# Processing Record 32 of Set 5 : maldonado
# Processing Record 33 of Set 5 : mantua
# Processing Record 34 of Set 5 : alim
# Processing Record 35 of Set 5 : torbay
# Processing Record 36 of Set 5 : florianopolis
# Processing Record 37 of Set 5 : sabang
# Processing Record 38 of Set 5 : russell
# Processing Record 39 of Set 5 : hithadhoo
# Processing Record 40 of Set 5 : mehamn
# Processing Record 41 of Set 5 : culebra
# Processing Record 42 of Set 5 : mchinji
# Processing Record 43 of Set 5 : juruti
# Processing Record 44 of Set 5 : vaitape
# Processing Record 45 of Set 5 : sehithwa
# Processing Record 46 of Set 5 : sao joao do paraiso
# Processing Record 47 of Set 5 : erenhot
# Processing Record 48 of Set 5 : santa maria da boa vista
# Processing Record 49 of Set 5 : aleksandrovskoye
# Processing Record 50 of Set 5 : radomsko
# Processing Record 0 of Set 6 : sao filipe
# Processing Record 1 of Set 6 : luangwa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 6 : zabid
# Processing Record 3 of Set 6 : marsa matruh
# Processing Record 4 of Set 6 : sao jose da coroa grande
# Processing Record 5 of Set 6 : kaitangata
# Processing Record 6 of Set 6 : arman
# Processing Record 7 of Set 6 : ambilobe
# Processing Record 8 of Set 6 : lata
# Processing Record 9 of Set 6 : luderitz
# Processing Record 10 of Set 6 : sitka
# Processing Record 11 of Set 6 : rocha
# Processing Record 12 of Set 6 : kapit
# Processing Record 13 of Set 6 : jeremie
# Processing Record 14 of Set 6 : high level
# Processing Record 15 of Set 6 : grand-santi
# Processing Record 16 of Set 6 : laoag
# Processing Record 17 of Set 6 : provideniya
# Processing Record 18 of Set 6 : timizart
# Processing Record 19 of Set 6 : dandong
# Processing Record 20 of Set 6 : ashikaga
# Processing Record 21 of Set 6 : nelson bay
# Processing Record 22 of Set 6 : naze
# Processing Record 23 of Set 6 : vestmannaeyjar
# Processing Record 24 of Set 6 : mbumi
# Processing Record 25 of Set 6 : viedma
# Processing Record 26 of Set 6 : catuday
# Processing Record 27 of Set 6 : sechura
# Processing Record 28 of Set 6 : mogadishu
# Processing Record 29 of Set 6 : sao pedro do sul
# Processing Record 30 of Set 6 : fort nelson
# Processing Record 31 of Set 6 : namatanai
# Processing Record 32 of Set 6 : pangnirtung
# Processing Record 33 of Set 6 : yaan
# Processing Record 34 of Set 6 : te anau
# Processing Record 35 of Set 6 : meulaboh
# Processing Record 36 of Set 6 : maumere
# Processing Record 37 of Set 6 : moreira sales
# Processing Record 38 of Set 6 : vanavara
# Processing Record 39 of Set 6 : ulaangom
# Processing Record 40 of Set 6 : avera
# City not found. Skipping...
# Processing Record 41 of Set 6 : les cayes
# Processing Record 42 of Set 6 : bambous virieux
# Processing Record 43 of Set 6 : lima
# Processing Record 44 of Set 6 : tadine
# Processing Record 45 of Set 6 : koslan
# Processing Record 46 of Set 6 : bonavista
# Processing Record 47 of Set 6 : coihaique
# Processing Record 48 of Set 6 : poum
# Processing Record 49 of Set 6 : luanda
# Processing Record 50 of Set 6 : laguna
# Processing Record 0 of Set 7 : port augusta
# Processing Record 1 of Set 7 : coolum beach
# Processing Record 2 of Set 7 : ahipara
# Processing Record 3 of Set 7 : shangqiu
# Processing Record 4 of Set 7 : margate
# Processing Record 5 of Set 7 : orocue
# Processing Record 6 of Set 7 : maracacume
# Processing Record 7 of Set 7 : nago
# Processing Record 8 of Set 7 : veraval
# Processing Record 9 of Set 7 : mezen
# Processing Record 10 of Set 7 : piterka
# Processing Record 11 of Set 7 : caravelas
# Processing Record 12 of Set 7 : cayenne
# Processing Record 13 of Set 7 : beian
# Processing Record 14 of Set 7 : tezu
# Processing Record 15 of Set 7 : vallenar
# Processing Record 16 of Set 7 : lamu
# Processing Record 17 of Set 7 : otuzco
# Processing Record 18 of Set 7 : kupang
# Processing Record 19 of Set 7 : ossora
# Processing Record 20 of Set 7 : papayal
# Processing Record 21 of Set 7 : yarensk
# Processing Record 22 of Set 7 : santiago del estero
# City not found. Skipping...
# Processing Record 23 of Set 7 : kloulklubed
# Processing Record 24 of Set 7 : tsuruoka
# Processing Record 25 of Set 7 : ballina
# Processing Record 26 of Set 7 : alofi
# Processing Record 27 of Set 7 : kargasok
# Processing Record 28 of Set 7 : mocuba
# Processing Record 29 of Set 7 : villamontes
# Processing Record 30 of Set 7 : sibolga
# Processing Record 31 of Set 7 : waverly
# City not found. Skipping...
# Processing Record 32 of Set 7 : portland
# Processing Record 33 of Set 7 : yar-sale
# Processing Record 34 of Set 7 : pathein
# Processing Record 35 of Set 7 : kholtoson
# Processing Record 36 of Set 7 : axim
# City not found. Skipping...
# Processing Record 37 of Set 7 : chone
# Processing Record 38 of Set 7 : moron
# Processing Record 39 of Set 7 : khorixas
# Processing Record 40 of Set 7 : truth or consequences
# Processing Record 41 of Set 7 : buenos aires
# Processing Record 42 of Set 7 : bayangol
# Processing Record 43 of Set 7 : kem
# Processing Record 44 of Set 7 : abnub
# Processing Record 45 of Set 7 : eqbaliyeh
# Processing Record 46 of Set 7 : piacabucu
# Processing Record 47 of Set 7 : zemio
# Processing Record 48 of Set 7 : waipawa
# Processing Record 49 of Set 7 : san patricio
# Processing Record 50 of Set 7 : zhuhai
# Processing Record 0 of Set 8 : tarko-sale
# City not found. Skipping...
# Processing Record 1 of Set 8 : nolinsk
# Processing Record 2 of Set 8 : launceston
# Processing Record 3 of Set 8 : guiyang
# Processing Record 4 of Set 8 : ottawa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 43 of Set 10 : christchurch
# Processing Record 44 of Set 10 : namibe
# Processing Record 45 of Set 10 : cartagena
# Processing Record 46 of Set 10 : ordu
# Processing Record 47 of Set 10 : bogatynia
# Processing Record 48 of Set 10 : terrak
# Processing Record 49 of Set 10 : surt
# Processing Record 50 of Set 10 : esmeraldas
# Processing Record 0 of Set 11 : hofn
# Processing Record 1 of Set 11 : ambon
# Processing Record 2 of Set 11 : melenki
# Processing Record 3 of Set 11 : aasiaat
# City not found. Skipping...
# Processing Record 4 of Set 11 : gunjur
# Processing Record 5 of Set 11 : zlobin
# Processing Record 6 of Set 11 : bautar
# Processing Record 7 of Set 11 : korla
# Processing Record 8 of Set 11 : ostrowiec swietokrzyski
# Processing Record 9 of Set 11 : hailar
# Processing Record 10 of Set 11 : montijo
# Processing Record 11 of Set 11 : mombetsu
# Processing Record 12 of Set 11 : nador
# Processing Record 13 of Set 11 : novoagansk
# Processing Record 14 of Set 11 : andippatti
# Processing Record 15 of Set 11 : alice springs
# Processing Record 16 of Set 11 : abonnema
# Processing Record 17 of Set 11 : ialibu
# Processing Record 18 of Set 11 : ramnagar
# Processing Record 19 of Set 11 : dejen
# Processing Record 20 of Set 11 : bajos de haina
# Processing Record 21 of Set 11 : parkersburg
# City not found. Skipping...
# Processing Record 22 of Set 11 : itamaraca
# Processing Record 23 of Set 11 : porto belo
# Processing Record 24 of Set 11 : hamilton
# Processing Record 25 of Set 11 : araguaina
# Processing Record 26 of Set 11 : yelyzavethradka
# Processing Record 27 of Set 11 : ozinki
# Processing Record 28 of Set 11 : agadez
# City not found. Skipping...
# Processing Record 29 of Set 11 : tecoanapa
# City not found. Skipping...
# Processing Record 30 of Set 11 : hambantota
# Processing Record 31 of Set 11 : porto walter
# Processing Record 32 of Set 11 : grindavik
# Processing Record 33 of Set 11 : sefton
# Processing Record 34 of Set 11 : richards bay
# Processing Record 35 of Set 11 : tete
# Processing Record 36 of Set 11 : lichuan
# Processing Record 37 of Set 11 : hudson bay
# Processing Record 38 of Set 11 : verkhnetulomskiy
# Processing Record 39 of Set 11 : zhigansk
# Processing Record 40 of Set 11 : shelburne
# Processing Record 41 of Set 11 : grand island
# Processing Record 42 of Set 11 : gogrial
# Processing Record 43 of Set 11 : bosaso
# Processing Record 44 of Set 11 : muisne
# Processing Record 45 of Set 11 : port-cartier
# Processing Record 46 of Set 11 : port moresby
# Processing Record 47 of Set 11 : nouadhibou
# Processing Record 48 of Set 11 : perico
# Processing Record 49 of Set 11 : lethem
# Processing Record 50 of Set 11 : sur
# City not found. Skipping...
# Processing Record 0 of Set 12 : long xuyen
# Processing Record 1 of Set 12 : roma
# Processing Record 2 of Set 12 : yumen
# Processing Record 3 of Set 12 : itarema
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
weather_dict.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %%
# Display the Data Frame
weather_dict
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0      Bredasdorp          65      ZA  1669846783        81 -34.5322
# 1    Kruisfontein           8      ZA  1669846573        72 -34.0033
# 2      Port Hardy          66      CA  1669846518        75  50.6996
# 3     Port Alfred         100      ZA  1669846559        94 -33.5906
# 4       Båtsfjord          75      NO  1669846784        86  70.6345
# ..            ...         ...     ...         ...       ...      ...
# 559           Sur          88      OM  1669846928        56  22.5667
# 560    Long Xuyen         100      VN  1669846929        93  10.3833
# 561          Rome         100      US  1669846643        88  43.2128
# 562         Yumen          66      CN  1669846929        78  40.2833
# 563       Itarema          92      BR  1669846929        73  -2.9248
#
#           Lng  Max Temp  Wind Speed
# 0     20.0403     63.12        2.44
# 1     24.7314     64.89        4.54
# 2   -127.4199     27.99       14.38
# 3     26.8910     66.18        1.01
# 4     29.7185     31.78        9.22
# ..        ...       ...         ...
# 559   59.5289     73.63        1.97
# 560  105.4167     76.95        3.51
# 561  -75.4557     41.38       12.66
# 562   97.2000      4.89        2.64
# 563  -39.9167     79.72       14.70
#
# [564 rows x 9 columns]

# %%
# Save city data into a csv file
weather_dict.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# Highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature drops.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# Polar regions have lower humidity and as latitude gets higher,humidity gets higher in southern hemisphere.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# Cloudiness data is widely spread across the latitude.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# Wind speed data is widely spread across the latitude.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.83

# %% [markdown]
# There is a strong negative correlation between latitude and max temperature for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.65

# %% [markdown]
# There is a moderate positive  correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.33

# %% [markdown]
# There is a  moderate positive correlation between latitude and humidity for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.2

# %% [markdown]
# There is a moderate positive correlation between latitude and humidity for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.22

# %% [markdown]
# There is a weak positive correlation between latitude and cloudiness for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# There is a weak positive correlation between latitude and cloudiness for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.12

# %% [markdown]
# There is a weak positive correlation between latitude and windspeed for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.36

# %% [markdown]
# There is a weak negative correlation between latitude and wind speed for southern hemisphere.
